# %%
import pandas as pd
import matplotlib.pyplot as plt
import requests
import numpy as np
from config import weather_api_key
from citipy import citipy
from datetime import datetime
import time

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs) #put it together
coordinates = list(lat_lngs)

# %%
cities = []  #list
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
    
len(cities)
# Out:
# 736

# %%
cities
# Out:
# ['souillac',
#  'una',
#  'taolanaro',
#  'huejuquilla el alto',
#  'nikolskoye',
#  'tuktoyaktuk',
#  'xam nua',
#  'busselton',
#  'asau',
#  'khatanga',
#  'bubaque',
#  'birjand',
#  'santa paula',
#  'hasaki',
#  'mumford',
#  'albany',
#  'jumla',
#  'gigmoto',
#  'murgab',
#  'mataura',
#  'tabas',
#  'rikitea',
#  'pierre',
#  'ust-kuyga',
#  'georgetown',
#  'beira',
#  'butaritari',
#  'salinas',
#  'hobart',
#  'salta',
#  'hermanus',
#  'jian',
#  'punta arenas',
#  'esna',
#  'hilo',
#  'contamana',
#  'aflu',
#  'kabinda',
#  'mys shmidta',
#  'viransehir',
#  'semnan',
#  'meadow lake',
#  'karamea',
#  'qaanaaq',
#  'vestmannaeyjar',
#  'bethel',
#  'kaseda',
#  'bluff',
#  'port elizabeth',
#  'konstantinovka',
#  'tabiauea',
#  'emerald',
#  'kahului',
#  'cairns',
#  'tosham',
#  'nioro',
#  'narrabri',
#  'kapaa',
#  'dinguiraye',
#  'atuona',
#  'saskylakh',
#  'imeni poliny osipenko',
#  'westport',
#  'severo-kurilsk',
#  'airai',
#  'imamoglu',
#  'cape town',
#  'ushuaia',
#  'lavrentiya',
#  'jamestown',
#  'yulara',
#  'dodge city',
#  'comodoro rivadavia',
#  'zolotinka',
#  'andros town',
#  'tiksi',
#  'kodiak',
#  'hambantota',
#  'port alfred',
#  'muros',
#  'coquimbo',
#  'drochtersen',
#  'narsaq',
#  'toliary',
#  'umzimvubu',
#  'manzhouli',
#  'barentsburg',
#  'adrar',
#  'carnarvon',
#  'vangaindrano',
#  'nobres',
#  'chokurdakh',
#  'cabo san lucas',
#  'aklavik',
#  'cherskiy',
#  'itoman',
#  'providencia',
#  'luanda',
#  'vaini',
#  'makakilo city',
#  'faanui',
#  'naryan-mar',
#  'hualmay',
#  'thompson',
#  'barrow',
#  'longyearbyen',
#  'port-gentil',
#  'sale',
#  'east london',
#  'puerto ayora',
#  'ilulissat',
#  'chuy',
#  'carikar',
#  'arraial do cabo',
#  'caravelas',
#  'lebu',
#  'bandarbeyla',
#  'mopti',
#  'lompoc',
#  'halalo',
#  'sola',
#  'weyburn',
#  'buta',
#  'sao filipe',
#  'sentyabrskiy',
#  'margate',
#  'tasiilaq',
#  'avarua',
#  'beloha',
#  'bambous virieux',
#  'illoqqortoormiut',
#  'hithadhoo',
#  'nome',
#  'yellowknife',
#  'huarmey',
#  'bengkulu',
#  'praia',
#  'lodja',
#  'ahipara',
#  'baykit',
#  'fairbanks',
#  'mar del plata',
#  'buchanan',
#  'avera',
#  'anadyr',
#  'broome',
#  'maunabo',
#  'buraydah',
#  'pevek',
#  'xuddur',
#  'torbay',
#  'eureka',
#  'castro',
#  'fortuna',
#  'saint-denis',
#  'dunedin',
#  'verkhnevilyuysk',
#  'copiapo',
#  'saint-francois',
#  'sabang',
#  'igarka',
#  'quarai',
#  'belaya gora',
#  'ojinaga',
#  'kruisfontein',
#  'ribeira grande',
#  'port hardy',
#  'srednekolymsk',
#  'boddam',
#  'severnyy',
#  'canico',
#  'vila velha',
#  'uyuni',
#  'atar',
#  'aden',
#  'flin flon',
#  'belushya guba',
#  'brae',
#  'smithers',
#  'zima',
#  'barstow',
#  'husavik',
#  'kemijarvi',
#  'samarai',
#  'nizhneyansk',
#  'drochia',
#  'bredasdorp',
#  'fort morgan',
#  'okhotsk',
#  'krasnoyarsk-45',
#  'tasbuget',
#  'the valley',
#  'salalah',
#  'geraldton',
#  'norman wells',
#  'omsukchan',
#  'kavieng',
#  'saint-philippe',
#  'portland',
#  'fort nelson',
#  'quatre cocos',
#  'kieta',
#  'clyde river',
#  'jingdezhen',
#  'darhan',
#  'dikson',
#  'saint-joseph',
#  'vila franca do campo',
#  'raudeberg',
#  'mount gambier',
#  'oistins',
#  'nouadhibou',
#  'marcona',
#  'leningradskiy',
#  'padang',
#  'tsihombe',
#  'kulhudhuffushi',
#  'datong',
#  'provideniya',
#  'san quintin',
#  'phan thiet',
#  'nurota',
#  'ust-nera',
#  'qingquan',
#  'miyang',
#  'cidreira',
#  'hofn',
#  'robstown',
#  'attawapiskat',
#  'lamesa',
#  'kaitangata',
#  'burns lake',
#  'bone',
#  'beringovskiy',
#  'muisne',
#  'bairiki',
#  'katsuura',
#  'saryshagan',
#  'new norfolk',
#  'komsomolskiy',
#  'san cristobal',
#  'pauini',
#  'amderma',
#  'kutum',
#  'qurunbaliyah',
#  'kaputa',
#  'levelland',
#  'kaeo',
#  'marang',
#  'moose factory',
#  'tessalit',
#  'topeka',
#  'gilgit',
#  'hihifo',
#  'lorengau',
#  'iquique',
#  'nanortalik',
#  'tarko-sale',
#  'alice springs',
#  'qingdao',
#  'arica',
#  'gasa',
#  'mantua',
#  'havoysund',
#  'grand river south east',
#  'casambalangan',
#  'upernavik',
#  'ancud',
#  'klaksvik',
#  'te anau',
#  'riviere-au-renard',
#  'malinyi',
#  'mandalgovi',
#  'labuhan',
#  'lata',
#  'homer',
#  'cassilandia',
#  'haines junction',
#  'egvekinot',
#  'balkanabat',
#  'guerrero negro',
#  'caaguazu',
#  'buala',
#  'kokorevka',
#  'harper',
#  'inhambane',
#  'mamallapuram',
#  'azrow',
#  'lagoa',
#  'fare',
#  'mahebourg',
#  'buqayq',
#  'pavlovo',
#  'obo',
#  'velingara',
#  'sur',
#  'cockburn town',
#  'filingue',
#  'broken hill',
#  'abu samrah',
#  'ponta do sol',
#  'hovd',
#  'dullewala',
#  'petropavlovsk-kamchatskiy',
#  'kavaratti',
#  'lixourion',
#  'paranhos',
#  'ilinskiy',
#  'kuching',
#  'grindavik',
#  'barga',
#  'turukhansk',
#  'teknaf',
#  'ostrovnoy',
#  'krompachy',
#  'guarda',
#  'ust-bolsheretsk',
#  'grand gaube',
#  'bentiu',
#  'silver city',
#  'ondangwa',
#  'karlshamn',
#  'mayumba',
#  'victoria',
#  'baishishan',
#  'saint-augustin',
#  'bur gabo',
#  'tsienyane',
#  'renigunta',
#  'hondo',
#  'henties bay',
#  'pueblo',
#  'great yarmouth',
#  'blind river',
#  'west odessa',
#  'san patricio',
#  'cascais',
#  'taltal',
#  'esperance',
#  'gladstone',
#  'moen',
#  'yichang',
#  'yerofey pavlovich',
#  'zolotkovo',
#  'luderitz',
#  'pitimbu',
#  'sisimiut',
#  'sungaipenuh',
#  'sitka',
#  'dingle',
#  'rabo de peixe',
#  'almeirim',
#  'mirnyy',
#  'krasnoselkup',
#  'nguiu',
#  'marawi',
#  'riyadh',
#  'vanavara',
#  'chifeng',
#  'puerto escondido',
#  'puerto leguizamo',
#  'kamenskoye',
#  'nalut',
#  'constitucion',
#  'yar-sale',
#  'ilhabela',
#  'saint george',
#  'balabac',
#  'bulanash',
#  'zemio',
#  'deutschlandsberg',
#  'mehamn',
#  'kindu',
#  'el sauzal',
#  'sidi ali',
#  'inongo',
#  'patterson',
#  'fort saint james',
#  'talara',
#  'ha tinh',
#  'saint anthony',
#  'berlevag',
#  'cintalapa',
#  'praya',
#  'wanxian',
#  'korla',
#  'jalu',
#  'dieppe',
#  'baley',
#  'ozerne',
#  'madang',
#  'louisbourg',
#  'supe',
#  'wuhu',
#  'guasdualito',
#  'teya',
#  'mana',
#  'balykshi',
#  'jutiapa',
#  'sandwick',
#  'muhos',
#  'sorvag',
#  'matara',
#  'ryotsu',
#  'areni',
#  'bonavista',
#  'kamaishi',
#  'terrace bay',
#  'palm valley',
#  'linxia',
#  'rokytne',
#  'shubarkuduk',
#  'sultepec',
#  'bud',
#  'wanning',
#  'malegaon',
#  'port blair',
#  'codrington',
#  'samusu',
#  'danielskuil',
#  'roald',
#  'puerto lopez',
#  'paamiut',
#  'zhezkazgan',
#  'glendive',
#  'hobyo',
#  'acarau',
#  'plettenberg bay',
#  'sangre grande',
#  'cayenne',
#  'prachuap khiri khan',
#  'buenavista',
#  'rolim de moura',
#  'cerkezkoy',
#  'chkalovskoye',
#  'mitsamiouli',
#  'karratha',
#  'shimoda',
#  'finschhafen',
#  'severnyy-kospashskiy',
#  'odienne',
#  'gat',
#  'mangrol',
#  'hamilton',
#  'ladushkin',
#  'male',
#  'sfantu gheorghe',
#  'fort oglethorpe',
#  'vanimo',
#  'vardo',
#  'la ronge',
#  'vila do maio',
#  'launceston',
#  'troitskoye',
#  'aksay',
#  'znamenskoye',
#  'chontalpa',
#  'port arthur',
#  'santa maria',
#  'pundaguitan',
#  'port shepstone',
#  'sarwar',
#  'stavern',
#  'karasburg',
#  'karauzyak',
#  'burkhala',
#  'kaniama',
#  'xichang',
#  'zhitikara',
#  'college',
#  'akyab',
#  'karpuninskiy',
#  'tecoanapa',
#  'namie',
#  'binabalian',
#  'bac giang',
#  'luang prabang',
#  'arroio grande',
#  'dawei',
#  'tautira',
#  'najran',
#  'coahuayana',
#  'valparaiso',
#  'amapa',
#  'pisco',
#  'mandan',
#  'anchorage',
#  'bara',
#  'viedma',
#  'diffa',
#  'zlate moravce',
#  'bathsheba',
#  'meyungs',
#  'villazon',
#  'mocuba',
#  'utiroa',
#  'ola',
#  'san juan',
#  'ambon',
#  'zunyi',
#  'lethem',
#  'bilma',
#  'talnakh',
#  'iqaluit',
#  'kyra',
#  'tuatapere',
#  'charyshskoye',
#  'bargal',
#  'sorland',
#  'kimbe',
#  'praia da vitoria',
#  'cuenca',
#  'monrovia',
#  'kathu',
#  'ngukurr',
#  'vila',
#  'aswan',
#  'san jeronimo',
#  'onega',
#  'pochutla',
#  'khunti',
#  'sibolga',
#  'konstantinovsk',
#  'abu kamal',
#  'port lincoln',
#  'sembakung',
#  'coihaique',
#  'port moresby',
#  'surgut',
#  'nortelandia',
#  'alta floresta',
#  'saint-pierre',
#  'otradnoye',
#  'balsas',
#  'khilok',
#  'galeras',
#  'grootfontein',
#  'port-cartier',
#  'langenburg',
#  'tezu',
#  'auki',
#  'minas',
#  'reutov',
#  'tual',
#  'saldanha',
#  'naze',
#  'liuzhou',
#  'ribas do rio pardo',
#  'carutapera',
#  'khanpur',
#  'hami',
#  'oudtshoorn',
#  'bardiyah',
#  'sicamous',
#  'xinan',
#  'kirkuk',
#  'kazalinsk',
#  'wadi musa',
#  'olafsvik',
#  'morant bay',
#  'grants pass',
#  'half moon bay',
#  'xining',
#  'kawalu',
#  'mitu',
#  'opuwo',
#  'severo-yeniseyskiy',
#  'palmer',
#  'welkom',
#  'iquitos',
#  'kununurra',
#  'kibala',
#  'legnago',
#  'deh rawud',
#  'tilichiki',
#  'bundaberg',
#  'iranshahr',
#  'pozo colorado',
#  'santa rosa',
#  'chulman',
#  'roebourne',
#  'skibbereen',
#  'bintulu',
#  'tumannyy',
#  'tukrah',
#  'dzhusaly',
#  'isla aguada',
#  'vao',
#  'los llanos de aridane',
#  'bontang',
#  'tiznit',
#  'puerto carreno',
#  'khandyga',
#  'vrangel',
#  'whitehorse',
#  'faya',
#  'conakry',
#  'chara',
#  'tortoli',
#  'zhigansk',
#  'port macquarie',
#  'laguna',
#  'namatanai',
#  'banda aceh',
#  'belmonte',
#  'saleaula',
#  'yumen',
#  'cap malheureux',
#  'grandview',
#  'manjeshwar',
#  'isangel',
#  'tateyama',
#  'eskil',
#  'wasilla',
#  'taoudenni',
#  'bay city',
#  'nuuk',
#  'corcoran',
#  'suntar',
#  'saint-georges',
#  'san carlos de bariloche',
#  'ixtapa',
#  'namibe',
#  'tiarei',
#  'invermere',
#  'tura',
#  'teluknaga',
#  'mossoro',
#  'rio gallegos',
#  'moron',
#  'januaria',
#  'boden',
#  'san policarpo',
#  'tsuruoka',
#  'halifax',
#  'rawson',
#  'lucera',
#  'altea',
#  'glens falls',
#  'namtsy',
#  'pousat',
#  'oranjemund',
#  'neiafu',
#  'dryden',
#  'luau',
#  'colares',
#  'prince rupert',
#  'inderborskiy',
#  'iralaya',
#  'tyukalinsk',
#  'seoul',
#  'kasongo-lunda',
#  'oussouye',
#  'aksu',
#  'jahrom',
#  'marsa matruh',
#  'montevideo',
#  'klyuchi',
#  'tabou',
#  'fayaoue',
#  'pervomayskoye',
#  'cabedelo',
#  'maceio',
#  'fallon',
#  'west bend',
#  'kimberley',
#  'malibu',
#  'dabat',
#  'liku',
#  'sept-iles',
#  'juneau',
#  'alofi',
#  'rocha',
#  'stornoway',
#  'tuyen quang',
#  'byron bay',
#  'sangar',
#  'kangaatsiaq',
#  'longlac',
#  'senneterre',
#  'ranghulu',
#  'atherton',
#  'lyantonde',
#  'acapulco',
#  'ust-kamchatsk',
#  'puerto rondon',
#  'biak',
#  'borovoy',
#  'vaitupu',
#  'iskateley',
#  'wakkanai',
#  'bolshegrivskoye',
#  'zonguldak',
#  'qaqortoq',
#  'kandalaksha',
#  'ballina',
#  'green valley',
#  'marsh harbour',
#  'atbasar',
#  'ramhormoz',
#  'doembang nangbuat',
#  'mahadday weyne',
#  'fevralsk',
#  'meulaboh',
#  'bacuit',
#  'koltsovo',
#  'samalaeulu',
#  'port hueneme',
#  'kaitong',
#  'dwarka',
#  'eldikan',
#  'wajima',
#  'bireun',
#  'mahajanga',
#  'poronaysk',
#  'udachnyy',
#  'peniche',
#  'katangli',
#  'umm kaddadah',
#  'comachuen',
#  'burica',
#  'manokwari',
#  'victor harbor',
#  'tres lagoas',
#  'kailua',
#  'emba',
#  'teahupoo',
#  'khani',
#  'wadi maliz',
#  'sao gabriel da cachoeira',
#  'antsohihy',
#  'bilibino',
#  'pacific grove',
#  'enshi',
#  'jepara',
#  'shitanjing']

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Print the beginning of the logging.
city_data = []
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_country = city_weather["sys"]["country"]
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        description = city_weather["weather"][0]["description"]
      
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | souillac
# Processing Record 2 of Set 1 | una
# Processing Record 3 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 1 | huejuquilla el alto
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | tuktoyaktuk
# Processing Record 7 of Set 1 | xam nua
# Processing Record 8 of Set 1 | busselton
# Processing Record 9 of Set 1 | asau
# Processing Record 10 of Set 1 | khatanga
# Processing Record 11 of Set 1 | bubaque
# Processing Record 12 of Set 1 | birjand
# Processing Record 13 of Set 1 | santa paula
# Processing Record 14 of Set 1 | hasaki
# Processing Record 15 of Set 1 | mumford
# Processing Record 16 of Set 1 | albany
# Processing Record 17 of Set 1 | jumla
# Processing Record 18 of Set 1 | gigmoto
# Processing Record 19 of Set 1 | murgab
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | tabas
# Processing Record 22 of Set 1 | rikitea
# Processing Record 23 of Set 1 | pierre
# Processing Record 24 of Set 1 | ust-kuyga
# Processing Record 25 of Set 1 | georgetown
# Processing Record 26 of Set 1 | beira
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | salinas
# Processing Record 29 of Set 1 | hobart
# Processing Record 30 of Set 1 | salta
# Processing Record 31 of Set 1 | hermanus
# Processing Record 32 of Set 1 | jian
# Processing Record 33 of Set 1 | punta arenas
# Processing Record 34 of Set 1 | esna
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | contamana
# Processing Record 37 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 38 of Set 1 | kabinda
# Processing Record 39 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 40 of Set 1 | viransehir
# Processing Record 41 of Set 1 | semnan
# Processing Record 42 of Set 1 | meadow lake
# Processing Record 43 of Set 1 | karamea
# City not found. Skipping...
# Processing Record 44 of Set 1 | qaanaaq
# Processing Record 45 of Set 1 | vestmannaeyjar
# Processing Record 46 of Set 1 | bethel
# Processing Record 47 of Set 1 | kaseda
# Processing Record 48 of Set 1 | bluff
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 50 of Set 1 | konstantinovka
# Processing Record 1 of Set 2 | tabiauea
# City not found. Skipping...
# Processing Record 2 of Set 2 | emerald
# Processing Record 3 of Set 2 | kahului
# Processing Record 4 of Set 2 | cairns
# Processing Record 5 of Set 2 | tosham
# Processing Record 6 of Set 2 | nioro
# Processing Record 7 of Set 2 | narrabri
# Processing Record 8 of Set 2 | kapaa
# Processing Record 9 of Set 2 | dinguiraye
# Processing Record 10 of Set 2 | atuona
# Processing Record 11 of Set 2 | saskylakh
# Processing Record 12 of Set 2 | imeni poliny osipenko
# Processing Record 13 of Set 2 | westport
# Processing Record 14 of Set 2 | severo-kurilsk
# Processing Record 15 of Set 2 | airai
# Processing Record 16 of Set 2 | imamoglu
# Processing Record 17 of Set 2 | cape town
# Processing Record 18 of Set 2 | ushuaia
# Processing Record 19 of Set 2 | lavrentiya
# Processing Record 20 of Set 2 | jamestown
# Processing Record 21 of Set 2 | yulara
# Processing Record 22 of Set 2 | dodge city
# Processing Record 23 of Set 2 | comodoro rivadavia
# Processing Record 24 of Set 2 | zolotinka
# City not found. Skipping...
# Processing Record 25 of Set 2 | andros town
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | kodiak
# Processing Record 28 of Set 2 | hambantota
# Processing Record 29 of Set 2 | port alfred
# Processing Record 30 of Set 2 | muros
# Processing Record 31 of Set 2 | coquimbo
# Processing Record 32 of Set 2 | drochtersen
# Processing Record 33 of Set 2 | narsaq
# Processing Record 34 of Set 2 | toliary
# City not found. Skipping...
# Processing Record 35 of Set 2 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 2 | manzhouli
# Processing Record 37 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 2 | adrar
# Processing Record 39 of Set 2 | carnarvon
# Processing Record 40 of Set 2 | vangaindrano
# Processing Record 41 of Set 2 | nobres
# Processing Record 42 of Set 2 | chokurdakh
# Processing Record 43 of Set 2 | cabo san lucas
# Processing Record 44 of Set 2 | aklavik
# Processing Record 45 of Set 2 | cherskiy
# Processing Record 46 of Set 2 | itoman
# Processing Record 47 of Set 2 | providencia
# Processing Record 48 of Set 2 | luanda
# Processing Record 49 of Set 2 | vaini
# Processing Record 50 of Set 2 | makakilo city
# Processing Record 1 of Set 3 | faanui
# Processing Record 2 of Set 3 | naryan-mar
# Processing Record 3 of Set 3 | hualmay
# Processing Record 4 of Set 3 | thompson
# Processing Record 5 of Set 3 | barrow
# Processing Record 6 of Set 3 | longyearbyen
# Processing Record 7 of Set 3 | port-gentil
# Processing Record 8 of Set 3 | sale
# Processing Record 9 of Set 3 | east london
# Processing Record 10 of Set 3 | puerto ayora
# Processing Record 11 of Set 3 | ilulissat
# Processing Record 12 of Set 3 | chuy
# Processing Record 13 of Set 3 | carikar
# City not found. Skipping...
# Processing Record 14 of Set 3 | arraial do cabo
# Processing Record 15 of Set 3 | caravelas
# Processing Record 16 of Set 3 | lebu
# Processing Record 17 of Set 3 | bandarbeyla
# Processing Record 18 of Set 3 | mopti
# Processing Record 19 of Set 3 | lompoc
# Processing Record 20 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 21 of Set 3 | sola
# Processing Record 22 of Set 3 | weyburn
# Processing Record 23 of Set 3 | buta
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 3 | margate
# Processing Record 27 of Set 3 | tasiilaq
# Processing Record 28 of Set 3 | avarua
# Processing Record 29 of Set 3 | beloha
# Processing Record 30 of Set 3 | bambous virieux
# Processing Record 31 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 32 of Set 3 | hithadhoo
# Processing Record 33 of Set 3 | nome
# Processing Record 34 of Set 3 | yellowknife
# Processing Record 35 of Set 3 | huarmey
# Processing Record 36 of Set 3 | bengkulu
# Processing Record 37 of Set 3 | praia
# Processing Record 38 of Set 3 | lodja
# Processing Record 39 of Set 3 | ahipara
# Processing Record 40 of Set 3 | baykit
# Processing Record 41 of Set 3 | fairbanks
# Processing Record 42 of Set 3 | mar del plata
# Processing Record 43 of Set 3 | buchanan
# Processing Record 44 of Set 3 | avera
# Processing Record 45 of Set 3 | anadyr
# Processing Record 46 of Set 3 | broome
# Processing Record 47 of Set 3 | maunabo
# Processing Record 48 of Set 3 | buraydah
# Processing Record 49 of Set 3 | pevek
# Processing Record 50 of Set 3 | xuddur
# Processing Record 1 of Set 4 | torbay
# Processing Record 2 of Set 4 | eureka
# Processing Record 3 of Set 4 | castro
# Processing Record 4 of Set 4 | fortuna
# Processing Record 5 of Set 4 | saint-denis
# Processing Record 6 of Set 4 | dunedin
# Processing Record 7 of Set 4 | verkhnevilyuysk
# Processing Record 8 of Set 4 | copiapo
# Processing Record 9 of Set 4 | saint-francois
# Processing Record 10 of Set 4 | sabang
# Processing Record 11 of Set 4 | igarka
# Processing Record 12 of Set 4 | quarai
# Processing Record 13 of Set 4 | belaya gora
# Processing Record 14 of Set 4 | ojinaga
# Processing Record 15 of Set 4 | kruisfontein
# Processing Record 16 of Set 4 | ribeira grande
# Processing Record 17 of Set 4 | port hardy
# Processing Record 18 of Set 4 | srednekolymsk
# Processing Record 19 of Set 4 | boddam
# Processing Record 20 of Set 4 | severnyy
# Processing Record 21 of Set 4 | canico
# Processing Record 22 of Set 4 | vila velha
# Processing Record 23 of Set 4 | uyuni
# Processing Record 24 of Set 4 | atar
# Processing Record 25 of Set 4 | aden
# Processing Record 26 of Set 4 | flin flon
# Processing Record 27 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 28 of Set 4 | brae
# Processing Record 29 of Set 4 | smithers
# Processing Record 30 of Set 4 | zima
# Processing Record 31 of Set 4 | barstow
# Processing Record 32 of Set 4 | husavik
# Processing Record 33 of Set 4 | kemijarvi
# Processing Record 34 of Set 4 | samarai
# Processing Record 35 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 36 of Set 4 | drochia
# Processing Record 37 of Set 4 | bredasdorp
# Processing Record 38 of Set 4 | fort morgan
# Processing Record 39 of Set 4 | okhotsk
# Processing Record 40 of Set 4 | krasnoyarsk-45
# City not found. Skipping...
# Processing Record 41 of Set 4 | tasbuget
# City not found. Skipping...
# Processing Record 42 of Set 4 | the valley
# Processing Record 43 of Set 4 | salalah
# Processing Record 44 of Set 4 | geraldton
# Processing Record 45 of Set 4 | norman wells
# Processing Record 46 of Set 4 | omsukchan
# Processing Record 47 of Set 4 | kavieng
# Processing Record 48 of Set 4 | saint-philippe
# Processing Record 49 of Set 4 | portland
# Processing Record 50 of Set 4 | fort nelson
# Processing Record 1 of Set 5 | quatre cocos
# Processing Record 2 of Set 5 | kieta
# Processing Record 3 of Set 5 | clyde river
# Processing Record 4 of Set 5 | jingdezhen
# Processing Record 5 of Set 5 | darhan
# Processing Record 6 of Set 5 | dikson
# Processing Record 7 of Set 5 | saint-joseph
# Processing Record 8 of Set 5 | vila franca do campo
# Processing Record 9 of Set 5 | raudeberg
# Processing Record 10 of Set 5 | mount gambier
# Processing Record 11 of Set 5 | oistins
# Processing Record 12 of Set 5 | nouadhibou
# Processing Record 13 of Set 5 | marcona
# City not found. Skipping...
# Processing Record 14 of Set 5 | leningradskiy
# Processing Record 15 of Set 5 | padang
# Processing Record 16 of Set 5 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 5 | kulhudhuffushi
# Processing Record 18 of Set 5 | datong
# Processing Record 19 of Set 5 | provideniya
# Processing Record 20 of Set 5 | san quintin
# Processing Record 21 of Set 5 | phan thiet
# Processing Record 22 of Set 5 | nurota
# Processing Record 23 of Set 5 | ust-nera
# Processing Record 24 of Set 5 | qingquan
# Processing Record 25 of Set 5 | miyang
# Processing Record 26 of Set 5 | cidreira
# Processing Record 27 of Set 5 | hofn
# Processing Record 28 of Set 5 | robstown
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | lamesa
# Processing Record 31 of Set 5 | kaitangata
# Processing Record 32 of Set 5 | burns lake
# Processing Record 33 of Set 5 | bone
# Processing Record 34 of Set 5 | beringovskiy
# Processing Record 35 of Set 5 | muisne
# Processing Record 36 of Set 5 | bairiki
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 39 of Set 5 | new norfolk
# Processing Record 40 of Set 5 | komsomolskiy
# Processing Record 41 of Set 5 | san cristobal
# Processing Record 42 of Set 5 | pauini
# Processing Record 43 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 44 of Set 5 | kutum
# Processing Record 45 of Set 5 | qurunbaliyah
# City not found. Skipping...
# Processing Record 46 of Set 5 | kaputa
# Processing Record 47 of Set 5 | levelland
# Processing Record 48 of Set 5 | kaeo
# Processing Record 49 of Set 5 | marang
# Processing Record 50 of Set 5 | moose factory
# Processing Record 1 of Set 6 | tessalit
# Processing Record 2 of Set 6 | topeka
# Processing Record 3 of Set 6 | gilgit
# Processing Record 4 of Set 6 | hihifo
# City not found. Skipping...
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | iquique
# Processing Record 7 of Set 6 | nanortalik
# Processing Record 8 of Set 6 | tarko-sale
# Processing Record 9 of Set 6 | alice springs
# Processing Record 10 of Set 6 | qingdao
# Processing Record 11 of Set 6 | arica
# Processing Record 12 of Set 6 | gasa
# Processing Record 13 of Set 6 | mantua
# Processing Record 14 of Set 6 | havoysund
# Processing Record 15 of Set 6 | grand river south east
# City not found. Skipping...
# Processing Record 16 of Set 6 | casambalangan
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | klaksvik
# Processing Record 20 of Set 6 | te anau
# Processing Record 21 of Set 6 | riviere-au-renard
# Processing Record 22 of Set 6 | malinyi
# Processing Record 23 of Set 6 | mandalgovi
# Processing Record 24 of Set 6 | labuhan
# Processing Record 25 of Set 6 | lata
# Processing Record 26 of Set 6 | homer
# Processing Record 27 of Set 6 | cassilandia
# Processing Record 28 of Set 6 | haines junction
# Processing Record 29 of Set 6 | egvekinot
# Processing Record 30 of Set 6 | balkanabat
# Processing Record 31 of Set 6 | guerrero negro
# Processing Record 32 of Set 6 | caaguazu
# Processing Record 33 of Set 6 | buala
# Processing Record 34 of Set 6 | kokorevka
# Processing Record 35 of Set 6 | harper
# Processing Record 36 of Set 6 | inhambane
# Processing Record 37 of Set 6 | mamallapuram
# Processing Record 38 of Set 6 | azrow
# City not found. Skipping...
# Processing Record 39 of Set 6 | lagoa
# Processing Record 40 of Set 6 | fare
# Processing Record 41 of Set 6 | mahebourg
# Processing Record 42 of Set 6 | buqayq
# City not found. Skipping...
# Processing Record 43 of Set 6 | pavlovo
# Processing Record 44 of Set 6 | obo
# Processing Record 45 of Set 6 | velingara
# Processing Record 46 of Set 6 | sur
# Processing Record 47 of Set 6 | cockburn town
# Processing Record 48 of Set 6 | filingue
# Processing Record 49 of Set 6 | broken hill
# Processing Record 50 of Set 6 | abu samrah
# Processing Record 1 of Set 7 | ponta do sol
# Processing Record 2 of Set 7 | hovd
# Processing Record 3 of Set 7 | dullewala
# Processing Record 4 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 5 of Set 7 | kavaratti
# Processing Record 6 of Set 7 | lixourion
# Processing Record 7 of Set 7 | paranhos
# Processing Record 8 of Set 7 | ilinskiy
# Processing Record 9 of Set 7 | kuching
# Processing Record 10 of Set 7 | grindavik
# Processing Record 11 of Set 7 | barga
# Processing Record 12 of Set 7 | turukhansk
# Processing Record 13 of Set 7 | teknaf
# Processing Record 14 of Set 7 | ostrovnoy
# Processing Record 15 of Set 7 | krompachy
# Processing Record 16 of Set 7 | guarda
# Processing Record 17 of Set 7 | ust-bolsheretsk
# City not found. Skipping...
# Processing Record 18 of Set 7 | grand gaube
# Processing Record 19 of Set 7 | bentiu
# Processing Record 20 of Set 7 | silver city
# Processing Record 21 of Set 7 | ondangwa
# Processing Record 22 of Set 7 | karlshamn
# Processing Record 23 of Set 7 | mayumba
# Processing Record 24 of Set 7 | victoria
# Processing Record 25 of Set 7 | baishishan
# Processing Record 26 of Set 7 | saint-augustin
# Processing Record 27 of Set 7 | bur gabo
# City not found. Skipping...
# Processing Record 28 of Set 7 | tsienyane
# City not found. Skipping...
# Processing Record 29 of Set 7 | renigunta
# Processing Record 30 of Set 7 | hondo
# Processing Record 31 of Set 7 | henties bay
# Processing Record 32 of Set 7 | pueblo
# Processing Record 33 of Set 7 | great yarmouth
# Processing Record 34 of Set 7 | blind river
# Processing Record 35 of Set 7 | west odessa
# Processing Record 36 of Set 7 | san patricio
# Processing Record 37 of Set 7 | cascais
# Processing Record 38 of Set 7 | taltal
# Processing Record 39 of Set 7 | esperance
# Processing Record 40 of Set 7 | gladstone
# Processing Record 41 of Set 7 | moen
# Processing Record 42 of Set 7 | yichang
# Processing Record 43 of Set 7 | yerofey pavlovich
# Processing Record 44 of Set 7 | zolotkovo
# Processing Record 45 of Set 7 | luderitz
# Processing Record 46 of Set 7 | pitimbu
# Processing Record 47 of Set 7 | sisimiut
# Processing Record 48 of Set 7 | sungaipenuh
# Processing Record 49 of Set 7 | sitka
# Processing Record 50 of Set 7 | dingle
# Processing Record 1 of Set 8 | rabo de peixe
# Processing Record 2 of Set 8 | almeirim
# Processing Record 3 of Set 8 | mirnyy
# Processing Record 4 of Set 8 | krasnoselkup
# Processing Record 5 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 6 of Set 8 | marawi
# Processing Record 7 of Set 8 | riyadh
# Processing Record 8 of Set 8 | vanavara
# Processing Record 9 of Set 8 | chifeng
# Processing Record 10 of Set 8 | puerto escondido
# Processing Record 11 of Set 8 | puerto leguizamo
# Processing Record 12 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 13 of Set 8 | nalut
# Processing Record 14 of Set 8 | constitucion
# Processing Record 15 of Set 8 | yar-sale
# Processing Record 16 of Set 8 | ilhabela
# Processing Record 17 of Set 8 | saint george
# Processing Record 18 of Set 8 | balabac
# Processing Record 19 of Set 8 | bulanash
# Processing Record 20 of Set 8 | zemio
# Processing Record 21 of Set 8 | deutschlandsberg
# Processing Record 22 of Set 8 | mehamn
# Processing Record 23 of Set 8 | kindu
# Processing Record 24 of Set 8 | el sauzal
# Processing Record 25 of Set 8 | sidi ali
# Processing Record 26 of Set 8 | inongo
# Processing Record 27 of Set 8 | patterson
# Processing Record 28 of Set 8 | fort saint james
# Processing Record 29 of Set 8 | talara
# Processing Record 30 of Set 8 | ha tinh
# Processing Record 31 of Set 8 | saint anthony
# Processing Record 32 of Set 8 | berlevag
# Processing Record 33 of Set 8 | cintalapa
# Processing Record 34 of Set 8 | praya
# Processing Record 35 of Set 8 | wanxian
# Processing Record 36 of Set 8 | korla
# Processing Record 37 of Set 8 | jalu
# Processing Record 38 of Set 8 | dieppe
# Processing Record 39 of Set 8 | baley
# Processing Record 40 of Set 8 | ozerne
# Processing Record 41 of Set 8 | madang
# Processing Record 42 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 43 of Set 8 | supe
# Processing Record 44 of Set 8 | wuhu
# Processing Record 45 of Set 8 | guasdualito
# Processing Record 46 of Set 8 | teya
# Processing Record 47 of Set 8 | mana
# Processing Record 48 of Set 8 | balykshi
# Processing Record 49 of Set 8 | jutiapa
# Processing Record 50 of Set 8 | sandwick
# Processing Record 1 of Set 9 | muhos
# Processing Record 2 of Set 9 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 9 | matara
# Processing Record 4 of Set 9 | ryotsu
# Processing Record 5 of Set 9 | areni
# Processing Record 6 of Set 9 | bonavista
# Processing Record 7 of Set 9 | kamaishi
# Processing Record 8 of Set 9 | terrace bay
# Processing Record 9 of Set 9 | palm valley
# Processing Record 10 of Set 9 | linxia
# Processing Record 11 of Set 9 | rokytne
# Processing Record 12 of Set 9 | shubarkuduk
# Processing Record 13 of Set 9 | sultepec
# Processing Record 14 of Set 9 | bud
# Processing Record 15 of Set 9 | wanning
# Processing Record 16 of Set 9 | malegaon
# Processing Record 17 of Set 9 | port blair
# Processing Record 18 of Set 9 | codrington
# Processing Record 19 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 9 | danielskuil
# Processing Record 21 of Set 9 | roald
# Processing Record 22 of Set 9 | puerto lopez
# Processing Record 23 of Set 9 | paamiut
# Processing Record 24 of Set 9 | zhezkazgan
# Processing Record 25 of Set 9 | glendive
# Processing Record 26 of Set 9 | hobyo
# Processing Record 27 of Set 9 | acarau
# Processing Record 28 of Set 9 | plettenberg bay
# Processing Record 29 of Set 9 | sangre grande
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | prachuap khiri khan
# Processing Record 32 of Set 9 | buenavista
# Processing Record 33 of Set 9 | rolim de moura
# City not found. Skipping...
# Processing Record 34 of Set 9 | cerkezkoy
# Processing Record 35 of Set 9 | chkalovskoye
# Processing Record 36 of Set 9 | mitsamiouli
# Processing Record 37 of Set 9 | karratha
# Processing Record 38 of Set 9 | shimoda
# Processing Record 39 of Set 9 | finschhafen
# Processing Record 40 of Set 9 | severnyy-kospashskiy
# Processing Record 41 of Set 9 | odienne
# Processing Record 42 of Set 9 | gat
# Processing Record 43 of Set 9 | mangrol
# Processing Record 44 of Set 9 | hamilton
# Processing Record 45 of Set 9 | ladushkin
# Processing Record 46 of Set 9 | male
# Processing Record 47 of Set 9 | sfantu gheorghe
# Processing Record 48 of Set 9 | fort oglethorpe
# Processing Record 49 of Set 9 | vanimo
# Processing Record 50 of Set 9 | vardo
# Processing Record 1 of Set 10 | la ronge
# Processing Record 2 of Set 10 | vila do maio
# Processing Record 3 of Set 10 | launceston
# Processing Record 4 of Set 10 | troitskoye
# Processing Record 5 of Set 10 | aksay
# Processing Record 6 of Set 10 | znamenskoye
# Processing Record 7 of Set 10 | chontalpa
# Processing Record 8 of Set 10 | port arthur
# Processing Record 9 of Set 10 | santa maria
# Processing Record 10 of Set 10 | pundaguitan
# Processing Record 11 of Set 10 | port shepstone
# Processing Record 12 of Set 10 | sarwar
# Processing Record 13 of Set 10 | stavern
# Processing Record 14 of Set 10 | karasburg
# Processing Record 15 of Set 10 | karauzyak
# City not found. Skipping...
# Processing Record 16 of Set 10 | burkhala
# City not found. Skipping...
# Processing Record 17 of Set 10 | kaniama
# Processing Record 18 of Set 10 | xichang
# Processing Record 19 of Set 10 | zhitikara
# City not found. Skipping...
# Processing Record 20 of Set 10 | college
# Processing Record 21 of Set 10 | akyab
# Processing Record 22 of Set 10 | karpuninskiy
# City not found. Skipping...
# Processing Record 23 of Set 10 | tecoanapa
# Processing Record 24 of Set 10 | namie
# Processing Record 25 of Set 10 | binabalian
# Processing Record 26 of Set 10 | bac giang
# Processing Record 27 of Set 10 | luang prabang
# Processing Record 28 of Set 10 | arroio grande
# Processing Record 29 of Set 10 | dawei
# Processing Record 30 of Set 10 | tautira
# Processing Record 31 of Set 10 | najran
# Processing Record 32 of Set 10 | coahuayana
# Processing Record 33 of Set 10 | valparaiso
# Processing Record 34 of Set 10 | amapa
# Processing Record 35 of Set 10 | pisco
# Processing Record 36 of Set 10 | mandan
# Processing Record 37 of Set 10 | anchorage
# Processing Record 38 of Set 10 | bara
# Processing Record 39 of Set 10 | viedma
# Processing Record 40 of Set 10 | diffa
# Processing Record 41 of Set 10 | zlate moravce
# Processing Record 42 of Set 10 | bathsheba
# Processing Record 43 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 44 of Set 10 | villazon
# Processing Record 45 of Set 10 | mocuba
# Processing Record 46 of Set 10 | utiroa
# City not found. Skipping...
# Processing Record 47 of Set 10 | ola
# Processing Record 48 of Set 10 | san juan
# Processing Record 49 of Set 10 | ambon
# Processing Record 50 of Set 10 | zunyi
# Processing Record 1 of Set 11 | lethem
# Processing Record 2 of Set 11 | bilma
# Processing Record 3 of Set 11 | talnakh
# Processing Record 4 of Set 11 | iqaluit
# Processing Record 5 of Set 11 | kyra
# Processing Record 6 of Set 11 | tuatapere
# Processing Record 7 of Set 11 | charyshskoye
# Processing Record 8 of Set 11 | bargal
# City not found. Skipping...
# Processing Record 9 of Set 11 | sorland
# Processing Record 10 of Set 11 | kimbe
# Processing Record 11 of Set 11 | praia da vitoria
# Processing Record 12 of Set 11 | cuenca
# Processing Record 13 of Set 11 | monrovia
# Processing Record 14 of Set 11 | kathu
# Processing Record 15 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 16 of Set 11 | vila
# Processing Record 17 of Set 11 | aswan
# Processing Record 18 of Set 11 | san jeronimo
# Processing Record 19 of Set 11 | onega
# Processing Record 20 of Set 11 | pochutla
# Processing Record 21 of Set 11 | khunti
# Processing Record 22 of Set 11 | sibolga
# Processing Record 23 of Set 11 | konstantinovsk
# Processing Record 24 of Set 11 | abu kamal
# Processing Record 25 of Set 11 | port lincoln
# Processing Record 26 of Set 11 | sembakung
# Processing Record 27 of Set 11 | coihaique
# Processing Record 28 of Set 11 | port moresby
# Processing Record 29 of Set 11 | surgut
# Processing Record 30 of Set 11 | nortelandia
# Processing Record 31 of Set 11 | alta floresta
# Processing Record 32 of Set 11 | saint-pierre
# Processing Record 33 of Set 11 | otradnoye
# Processing Record 34 of Set 11 | balsas
# Processing Record 35 of Set 11 | khilok
# Processing Record 36 of Set 11 | galeras
# Processing Record 37 of Set 11 | grootfontein
# Processing Record 38 of Set 11 | port-cartier
# Processing Record 39 of Set 11 | langenburg
# Processing Record 40 of Set 11 | tezu
# Processing Record 41 of Set 11 | auki
# Processing Record 42 of Set 11 | minas
# Processing Record 43 of Set 11 | reutov
# Processing Record 44 of Set 11 | tual
# Processing Record 45 of Set 11 | saldanha
# Processing Record 46 of Set 11 | naze
# Processing Record 47 of Set 11 | liuzhou
# Processing Record 48 of Set 11 | ribas do rio pardo
# Processing Record 49 of Set 11 | carutapera
# Processing Record 50 of Set 11 | khanpur
# Processing Record 1 of Set 12 | hami
# Processing Record 2 of Set 12 | oudtshoorn
# Processing Record 3 of Set 12 | bardiyah
# Processing Record 4 of Set 12 | sicamous
# Processing Record 5 of Set 12 | xinan
# Processing Record 6 of Set 12 | kirkuk
# Processing Record 7 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 8 of Set 12 | wadi musa
# Processing Record 9 of Set 12 | olafsvik
# Processing Record 10 of Set 12 | morant bay
# Processing Record 11 of Set 12 | grants pass
# Processing Record 12 of Set 12 | half moon bay
# Processing Record 13 of Set 12 | xining
# Processing Record 14 of Set 12 | kawalu
# Processing Record 15 of Set 12 | mitu
# Processing Record 16 of Set 12 | opuwo
# Processing Record 17 of Set 12 | severo-yeniseyskiy
# Processing Record 18 of Set 12 | palmer
# Processing Record 19 of Set 12 | welkom
# Processing Record 20 of Set 12 | iquitos
# Processing Record 21 of Set 12 | kununurra
# Processing Record 22 of Set 12 | kibala
# Processing Record 23 of Set 12 | legnago
# Processing Record 24 of Set 12 | deh rawud
# City not found. Skipping...
# Processing Record 25 of Set 12 | tilichiki
# Processing Record 26 of Set 12 | bundaberg
# Processing Record 27 of Set 12 | iranshahr
# Processing Record 28 of Set 12 | pozo colorado
# Processing Record 29 of Set 12 | santa rosa
# Processing Record 30 of Set 12 | chulman
# Processing Record 31 of Set 12 | roebourne
# Processing Record 32 of Set 12 | skibbereen
# Processing Record 33 of Set 12 | bintulu
# Processing Record 34 of Set 12 | tumannyy
# City not found. Skipping...
# Processing Record 35 of Set 12 | tukrah
# Processing Record 36 of Set 12 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 12 | isla aguada
# Processing Record 38 of Set 12 | vao
# Processing Record 39 of Set 12 | los llanos de aridane
# Processing Record 40 of Set 12 | bontang
# Processing Record 41 of Set 12 | tiznit
# Processing Record 42 of Set 12 | puerto carreno
# Processing Record 43 of Set 12 | khandyga
# Processing Record 44 of Set 12 | vrangel
# Processing Record 45 of Set 12 | whitehorse
# Processing Record 46 of Set 12 | faya
# Processing Record 47 of Set 12 | conakry
# Processing Record 48 of Set 12 | chara
# Processing Record 49 of Set 12 | tortoli
# Processing Record 50 of Set 12 | zhigansk
# Processing Record 1 of Set 13 | port macquarie
# Processing Record 2 of Set 13 | laguna
# Processing Record 3 of Set 13 | namatanai
# Processing Record 4 of Set 13 | banda aceh
# Processing Record 5 of Set 13 | belmonte
# Processing Record 6 of Set 13 | saleaula
# City not found. Skipping...
# Processing Record 7 of Set 13 | yumen
# Processing Record 8 of Set 13 | cap malheureux
# Processing Record 9 of Set 13 | grandview
# Processing Record 10 of Set 13 | manjeshwar
# Processing Record 11 of Set 13 | isangel
# Processing Record 12 of Set 13 | tateyama
# Processing Record 13 of Set 13 | eskil
# Processing Record 14 of Set 13 | wasilla
# Processing Record 15 of Set 13 | taoudenni
# Processing Record 16 of Set 13 | bay city
# Processing Record 17 of Set 13 | nuuk
# Processing Record 18 of Set 13 | corcoran
# Processing Record 19 of Set 13 | suntar
# Processing Record 20 of Set 13 | saint-georges
# Processing Record 21 of Set 13 | san carlos de bariloche
# Processing Record 22 of Set 13 | ixtapa
# Processing Record 23 of Set 13 | namibe
# Processing Record 24 of Set 13 | tiarei
# Processing Record 25 of Set 13 | invermere
# Processing Record 26 of Set 13 | tura
# Processing Record 27 of Set 13 | teluknaga
# Processing Record 28 of Set 13 | mossoro
# Processing Record 29 of Set 13 | rio gallegos
# Processing Record 30 of Set 13 | moron
# Processing Record 31 of Set 13 | januaria
# Processing Record 32 of Set 13 | boden
# Processing Record 33 of Set 13 | san policarpo
# Processing Record 34 of Set 13 | tsuruoka
# Processing Record 35 of Set 13 | halifax
# Processing Record 36 of Set 13 | rawson
# Processing Record 37 of Set 13 | lucera
# Processing Record 38 of Set 13 | altea
# Processing Record 39 of Set 13 | glens falls
# Processing Record 40 of Set 13 | namtsy
# Processing Record 41 of Set 13 | pousat
# City not found. Skipping...
# Processing Record 42 of Set 13 | oranjemund
# Processing Record 43 of Set 13 | neiafu
# Processing Record 44 of Set 13 | dryden
# Processing Record 45 of Set 13 | luau
# Processing Record 46 of Set 13 | colares
# Processing Record 47 of Set 13 | prince rupert
# Processing Record 48 of Set 13 | inderborskiy
# City not found. Skipping...
# Processing Record 49 of Set 13 | iralaya
# Processing Record 50 of Set 13 | tyukalinsk
# Processing Record 1 of Set 14 | seoul
# Processing Record 2 of Set 14 | kasongo-lunda
# Processing Record 3 of Set 14 | oussouye
# Processing Record 4 of Set 14 | aksu
# Processing Record 5 of Set 14 | jahrom
# City not found. Skipping...
# Processing Record 6 of Set 14 | marsa matruh
# Processing Record 7 of Set 14 | montevideo
# Processing Record 8 of Set 14 | klyuchi
# Processing Record 9 of Set 14 | tabou
# Processing Record 10 of Set 14 | fayaoue
# Processing Record 11 of Set 14 | pervomayskoye
# Processing Record 12 of Set 14 | cabedelo
# Processing Record 13 of Set 14 | maceio
# Processing Record 14 of Set 14 | fallon
# Processing Record 15 of Set 14 | west bend
# Processing Record 16 of Set 14 | kimberley
# Processing Record 17 of Set 14 | malibu
# Processing Record 18 of Set 14 | dabat
# Processing Record 19 of Set 14 | liku
# Processing Record 20 of Set 14 | sept-iles
# Processing Record 21 of Set 14 | juneau
# Processing Record 22 of Set 14 | alofi
# Processing Record 23 of Set 14 | rocha
# Processing Record 24 of Set 14 | stornoway
# Processing Record 25 of Set 14 | tuyen quang
# Processing Record 26 of Set 14 | byron bay
# Processing Record 27 of Set 14 | sangar
# Processing Record 28 of Set 14 | kangaatsiaq
# Processing Record 29 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 30 of Set 14 | senneterre
# Processing Record 31 of Set 14 | ranghulu
# Processing Record 32 of Set 14 | atherton
# Processing Record 33 of Set 14 | lyantonde
# Processing Record 34 of Set 14 | acapulco
# Processing Record 35 of Set 14 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 36 of Set 14 | puerto rondon
# Processing Record 37 of Set 14 | biak
# Processing Record 38 of Set 14 | borovoy
# Processing Record 39 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 14 | iskateley
# Processing Record 41 of Set 14 | wakkanai
# Processing Record 42 of Set 14 | bolshegrivskoye
# City not found. Skipping...
# Processing Record 43 of Set 14 | zonguldak
# Processing Record 44 of Set 14 | qaqortoq
# Processing Record 45 of Set 14 | kandalaksha
# Processing Record 46 of Set 14 | ballina
# Processing Record 47 of Set 14 | green valley
# Processing Record 48 of Set 14 | marsh harbour
# Processing Record 49 of Set 14 | atbasar
# Processing Record 50 of Set 14 | ramhormoz
# Processing Record 1 of Set 15 | doembang nangbuat
# Processing Record 2 of Set 15 | mahadday weyne
# City not found. Skipping...
# Processing Record 3 of Set 15 | fevralsk
# City not found. Skipping...
# Processing Record 4 of Set 15 | meulaboh
# Processing Record 5 of Set 15 | bacuit
# City not found. Skipping...
# Processing Record 6 of Set 15 | koltsovo
# Processing Record 7 of Set 15 | samalaeulu
# City not found. Skipping...
# Processing Record 8 of Set 15 | port hueneme
# Processing Record 9 of Set 15 | kaitong
# Processing Record 10 of Set 15 | dwarka
# Processing Record 11 of Set 15 | eldikan
# City not found. Skipping...
# Processing Record 12 of Set 15 | wajima
# Processing Record 13 of Set 15 | bireun
# Processing Record 14 of Set 15 | mahajanga
# Processing Record 15 of Set 15 | poronaysk
# Processing Record 16 of Set 15 | udachnyy
# Processing Record 17 of Set 15 | peniche
# Processing Record 18 of Set 15 | katangli
# Processing Record 19 of Set 15 | umm kaddadah
# Processing Record 20 of Set 15 | comachuen
# Processing Record 21 of Set 15 | burica
# City not found. Skipping...
# Processing Record 22 of Set 15 | manokwari
# Processing Record 23 of Set 15 | victor harbor
# Processing Record 24 of Set 15 | tres lagoas
# Processing Record 25 of Set 15 | kailua
# Processing Record 26 of Set 15 | emba
# Processing Record 27 of Set 15 | teahupoo
# Processing Record 28 of Set 15 | khani
# Processing Record 29 of Set 15 | wadi maliz
# Processing Record 30 of Set 15 | sao gabriel da cachoeira
# Processing Record 31 of Set 15 | antsohihy
# Processing Record 32 of Set 15 | bilibino
# Processing Record 33 of Set 15 | pacific grove
# Processing Record 34 of Set 15 | enshi
# Processing Record 35 of Set 15 | jepara
# Processing Record 36 of Set 15 | shitanjing
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
df = pd.DataFrame(city_data)
df.head(3)
# Out:
#                   City Country      Lat       Lng  Max Temp  Humidity  \
# 0             Souillac      MU -20.5167   57.5167     74.35        78
# 1                  Una      IN  20.8167   71.0333     73.09        44
# 2  Huejuquilla El Alto      MX  22.6000 -103.8667     73.13        34
#
#    Cloudiness  Wind Speed Current Description
# 0          20        3.44          few clouds
# 1          82       10.87       broken clouds
# 2          59        4.38       broken clouds

# %%
#Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
#Export 
df.to_csv(output_data_file, index_label="City_ID")
